# %%
#!/usr/bin/python3
# -*- coding: utf-8 -*-
'''''''''''''''''''''''''''''''''''''''''''''''''''''''''
### Alias : FATI.Main.py & Last Modded : 2021.08.31. ###
Zumi Library Reference : https://learn.robolink.com/docs/zumi-library
FATI 대회 공지 : https://sites.google.com/view/2021fati/%ED%8F%89%EA%B0%80-%EB%B0%A9%EC%8B%9D

2021 FATI 평가 방식
-0점부터 동작별 가산 점수를 부여함. 총점: +200점(보너스 +30점 미포함)
-출발점에 Zumi를 놓고 QR 및 색상카드를 인식하여 올바른 경로를 주행하도록 진행
-각 A, B, C 파트 별 점수를 내어 합산 후 총점이 높은 순으로 평가.
-총점 : 200점 (A코스: 80점, B코스: 50점, C코스: 70점)
-보너스 : 30점
-최대 획득 가능 점수 : 230점

보너스 점수
-구현 시 코스별 구현을 통해 실제 주행시
*A course - 잠시 정지- B course - 잠시 정지 - C course가 가능하지만
 전체 트랙을 코스 구분 없이 한번에 코딩한 경우 보너스 부여: +20점
-재배치 없이 한번에 완주 시 보너스 부여: +10점
-경로 이탈시마다 5점의 감점을 부여하며 재배치를 진행함.

동점자 처리 기준 (총점이 같은 경우) :
-저학년일수록
-빨리 도착점에 들어왔을수록 높은 순위를 부여함.
(시간 측정 방법: 출발 시 도레미음이 끝나자마자 측정이 시작되며, 마지막 도착지점에 들어가는 순간 측정이 종료됩니다. 따라서 웃거나 춤을 추는 시간은 측정되지 않습니다.)
'''''''''''''''''''''''''''''''''''''''''''''''''''''''''


import sys
import time
from collections import Counter

from zumi.zumi import Zumi
from zumi.protocol import Note  # to play sounds
from zumi.util.camera import Camera
from zumi.util.vision import Vision  # to recognize qr code
from zumi.util.screen import Screen
from zumi.util.color_classifier import ColorClassifier


class TeamOverload(object):
    def __init__(self, demo_name=None):
        self.camera = Camera()
        self.vision = Vision()
        self.screen = Screen()
        self.zumi = Zumi()

        if demo_name is None:
            self.demo_name = ["", "Parking_1500_8444", "All_400_8444"]
        else:
            self.demo_name = demo_name
            print("demo_name argument %s, %s detected!\n" % (demo_name[1], demo_name[2]))
        self.knn_parking = ColorClassifier(demo_name=self.demo_name[1], user_name="Overload")
        self.knn_trafficlight = ColorClassifier(demo_name=self.demo_name[2], user_name="Overload")
        self.knn_parking.fit("hsv")
        self.knn_trafficlight.fit("hsv")

        self.camera.start_camera()
        self.screen.draw_text_center("Team.Overload")

    def __del__(self):
        try:
            self.camera.close()
            self.zumi.stop()
        except Exception:
            pass
        print("------------- zumi stopped")

    def play_DoReMi(self):
        """play Do-Re-Mi"""
        self.zumi.play_note(Note.C4)
        self.zumi.play_note(Note.D4)
        self.zumi.play_note(Note.E4)

    def play_NextLevel(self, tempo=420):
        """play aespa NextLevel"""
        [self.zumi.play_note(n[0], n[1]*tempo) for n in [
            (Note.CS4, 0.5), (Note.FS4, 0.75), (Note.CS4, 1.75), (Note.FS4, 3),
            (Note.FS4, 0.5), (Note.FS4, 0.5), (Note.FS4, 0.5), (Note.FS4, 0.5), (Note.FS4, 0.5), (Note.E4, 1), (Note.FS4, 1),
            (Note.FS4, 0.5), (Note.FS4, 0.5), (Note.FS4, 0.5), (Note.FS4, 0.5), (Note.FS4, 0.5), (Note.E4, 1), (Note.FS4, 1),
            (Note.CS4, 0.5), (Note.FS4, 0.5), (Note.CS4, 0.5), (Note.FS4, 1),
            (Note.CS4, 0.5), (Note.FS4, 0.75), (Note.CS4, 1.75), (Note.FS4, 3),
            (Note.FS4, 0.5), (Note.FS4, 0.5), (Note.FS4, 0.5), (Note.FS4, 0.5), (Note.FS4, 0.5), (Note.E4, 1), (Note.FS4, 1),
            (Note.FS4, 0.5), (Note.FS4, 0.5), (Note.FS4, 0.5), (Note.FS4, 0.5), (Note.FS4, 0.5), (Note.E4, 0.5), (Note.FS4, 2.5),
            (Note.FS2, 1), (Note.FS3, 1.25), (Note.FS2, 0.25), (Note.FS3, 0.75), (Note.A2, 1.25), (Note.B2, 1.5),
            (Note.FS2, 1), (Note.FS3, 1.25), (Note.FS2, 0.25), (Note.FS3, 0.75), (Note.A2, 1.25), (Note.B2, 1.5),
            (Note.FS2, 1), (Note.FS3, 1.25), (Note.FS2, 0.25), (Note.FS3, 0.75), (Note.A2, 1.25), (Note.B2, 1.5),
            (Note.FS2, 1), (Note.FS3, 1.25), (Note.FS2, 0.25), (Note.FS3, 0.75), (Note.A2, 1.25), (Note.B2, 1.5),
            (Note.FS2, 1), (Note.FS3, 1.25), (Note.FS2, 0.25), (Note.FS3, 0.75), (Note.A2, 1.25), (Note.B2, 1.5),
            (Note.FS2, 1), (Note.FS3, 1.25), (Note.FS2, 0.25), (Note.FS3, 0.75), (Note.A2, 1.25), (Note.B2, 1.5),
            (Note.FS2, 1), (Note.FS3, 1.25), (Note.FS2, 0.25), (Note.FS3, 0.75), (Note.A2, 1.25), (Note.B2, 1.5),
            (Note.FS2, 1), (Note.FS3, 1.25), (Note.FS2, 0.25), (Note.FS3, 0.75), (Note.A2, 1.25), (Note.B2, 1.5)
        ]]

    def color_detector(self, knn, len=5, unity=True):
        retry = True
        while retry:
            predicts = []
            for i in range(1, len+1, 1):
                image = self.camera.capture()
                predicts.append(knn.predict(image))
                self.screen.draw_text_center("%d/%d" % (i, len))
            print(predicts)
            retry = False
            common = Counter(predicts).most_common()
            if unity:  # 유일성 보장
                for c in common[1:]:
                    if c[1] == common[0][1]:
                        print("unity of prediction cannot be guaranteed. retry!")
                        self.screen.draw_text_center("retry!!")
                        retry = True
            else:  # 동일한 빈도수의 값이 나온 경우 문제 발생.
                pass
            result = common[0][0]
        print("color_detector result : " + result)
        self.screen.draw_text_center(result + " detected")
        return result

    def restricted_color_detector(self, knn=None, len=5, unity=True):
        """Blue, Orange, Yellow 구분에만 사용하기 위해 만든 메서드
        *  'sv' : real Blue -> Blue, real orange -> Blue, real Yellow -> Yellow
           'hs' : real Blue -> Blue Orange, real orange -> Blue, real Yellow ->Blue
        *  'hv' : real Blue -> Yellow, real Orange -> Blue, real Yellow -> Blue
           'h' : real Blue -> Yellow, real orange -> Blue, real Yellow -> Blue
           's' : real Blue -> Blue, real orange -> Blue, real Yellow -> Blue or Yellow or Orange
           'v' : real Blue -> Yellow, real orange -> Blue or Yellow, real Yellow -> Yellow
           so, use 'sv' to separate Yellow from the others, and use 'hv' to distinguish blue from yellow
           (if hv yellow then blue, and hv blue then orange)
        """
        if knn is None:
            knn = self.knn_parking
        knn.fit("sv")

        retry = True
        while retry:
            predicts = []
            for i in range(1, len+1, 1):
                image = self.camera.capture()
                if knn.predict(image) == "Yellow":
                    result = "Yellow"
                else:
                    knn.fit("hv")
                    if knn.predict(image) == "Blue":
                        result = "Orange"
                    else:  # prediction == "Yellow"
                        result = "Blue"
                    knn.fit("sv")
                predicts.append(result)
                self.screen.draw_text_center("%d/%d" % (i, len))
            print(predicts)
            retry = False
            common = Counter(predicts).most_common()
            if unity:  # 유일성 보장
                for c in common[1:]:
                    if c[1] == common[0][1]:
                        print("unity of prediction cannot be guaranteed. retry!")
                        self.screen.draw_text_center("retry!!")
                        retry = True
            else:  # 동일한 빈도수의 값이 나온 경우 문제 발생.
                pass
            result = common[0][0]
        print("color_detector result : " + result)
        self.screen.draw_text_center(result + " detected")
        knn.fit("hsv")
        return result

    def qr_detector(self):
        image = self.camera.capture()
        qr_code = self.vision.find_QR_code(image)
        if qr_code is not None:
            message = self.vision.get_QR_message(qr_code)
            print("qr resolver input : " + message)
            resolved = eval(message)
            result = "Left" if resolved % 2 == 0 else "Right"
            print(">> eval(message) is %d, so turn %s" % (resolved, result))
            self.screen.draw_text_center("%d -> turn " % (resolved) + result)
            try:
                self.camera.show_image(image)
                self.camera.clear_output()
            finally:
                return result
        return None

    def print_face(self):
        self.screen.draw_image_by_name("zumi_face_by_overload")

    def trace_line(self, threshold=[95, 30], turnspd=[5, 0], forwardspd=7, motordiff=13,
                   stopcount=15, turndir="Stop", frontsensor=0, duration=0):
        """ do not run this method with threading/thread/multiprocessing
            motordiff cannot be negative
            turndir == "Stop" -> stop when both white
            turndir == "Left" -> turn left when both white
            turndir == "Right" -> turn right when both white
            turndir == "None" -> go forward when both white and find both black site
            frontsensor mode 0 -> disable front sensor
            frontsensor mode 1 -> stop zumi when object detected
            frontsensor mode 2 -> reverse zumi when object detected (and restore when object is no longer detected)
            duration == 0 -> do not check elapsed time
            duration > 0 -> if elapsed > duration then stop
        """
        get_data = self.zumi.get_all_IR_data
        ctrl_motors = self.zumi.control_motors

        def set_motors(left, right):
            ctrl_motors(right, left)

        self.zumi.reset_drive()

        stopline_detected = 0
        obstacle_detected = False

        motordiff = abs(motordiff)
        #drive_mode = 0

        start = time.time()

        try:
            while True:
                front_r, bottom_r, _, bottom_l, _, front_l = get_data()
                print(bottom_l, bottom_r, "|", front_l, front_r)

                if duration and duration <= time.time()-start:
                    print("time out")
                    raise KeyboardInterrupt

                if frontsensor and (front_l < threshold[1] and front_r < threshold[1]) if not obstacle_detected else \
                                   (front_l > threshold[1] or front_r > threshold[1]):  # val > thresh : nothing detected
                    if frontsensor == 1:
                        print("obstacle detected")
                        raise KeyboardInterrupt
                    elif frontsensor == 2:
                        turnspd[0] *= -1
                        turnspd[1] *= -1
                        forwardspd *= -1
                        obstacle_detected = not obstacle_detected
                        print("obstacle detected" if obstacle_detected else "obstacle removed")

                forwardspd_l = forwardspd+abs(motordiff)*(1 if forwardspd > 0 else -1 if forwardspd < 0 else 0)
                turnspd_l = [turnspd[0]+abs(motordiff)*(1 if turnspd[0] > 0 else -1 if turnspd[0] < 0 else 0),
                             turnspd[1]+abs(motordiff)*(1 if turnspd[1] > 0 else -1 if turnspd[1] < 0 else 0)]
                if bottom_l >= threshold[0] and bottom_r >= threshold[0]:  # both black
                    #if drive_mode != 1:
                    set_motors(forwardspd_l, forwardspd)
                    #    drive_mode = 1
                    print("> go forward")
                    if stopline_detected and turndir == "None":
                        raise KeyboardInterrupt
                    else:
                        stopline_detected = 0
                elif bottom_l < threshold[0] and bottom_r >= threshold[0]:  # left white
                    #if drive_mode != 2:
                    set_motors(turnspd_l[0], turnspd[1])  # turn right
                    #    drive_mode = 2
                    print("> turn right")
                    if stopline_detected and turndir != "None":
                        stopline_detected = 0
                elif bottom_l >= threshold[0] and bottom_r < threshold[0]:  # right white
                    #if drive_mode != 3:
                    set_motors(turnspd_l[1], turnspd[0])  # turn left
                    #    drive_mode = 3
                    print("> turn left")
                    if stopline_detected and turndir != "None":
                        stopline_detected = 0
                else:  # both white
                    stopline_detected += 1
                    print(">> stopline_detected")
                    if stopline_detected >= stopcount // (forwardspd+1//2):
                        if turndir == "Left":
                            #if drive_mode != 4:
                            set_motors(turnspd_l[1], turnspd[0])  # turn left
                            #    drive_mode = 4
                            print("> stopline_detected && turn left")
                        elif turndir == "Right":
                            #if drive_mode != 5:
                            set_motors(turnspd_l[0], turnspd[1])  # turn right
                            #    drive_mode = 5
                            print("> stopline_detected && turn right")
                        elif turndir == "None":
                            #if drive_mode != 6:
                            set_motors(turnspd_l[0], turnspd[0])
                            #    drive_mode = 6
                            print("> stopline_detected && go forward")
                        else:
                            raise KeyboardInterrupt
        except KeyboardInterrupt:
            self.zumi.stop()
            print("-- a stop sign found --")

    def trace_line_PID(self, threshold=100, turnspd=5, forwardspd=10, stopsign=15, turndir="Stop", frontsensor=0):
        """ do not run this method with threading/thread/multiprocessing
            turndir == "Stop" -> stop when both white
            turndir == "Left" -> turn left when both white
            turndir == "Right" -> turn right when both white
            turndir == "None" -> go forward when both white
            frontsensor mode 0 -> disable front sensor
            frontsensor mode 1 -> stop zumi when object detected
            frontsensor mode 2 -> reverse zumi when object detected (and restore when object is no longer detected)
        """
        get_data = self.zumi.get_all_IR_data
        drive = self.zumi.drive_at_angle
        read_z = self.zumi.read_z_angle

        stopline_detected = 0
        obstacle_detected = False
        drive_mode = -1

        # PID Values
        k_p = self.zumi.D_P
        k_i = self.zumi.D_I
        k_d = self.zumi.D_D
        self.zumi.reset_PID()

        max_speed = 127
        accuracy = 1.0

        try:
            while True:
                front_r, bottom_r, _, bottom_l, _, front_l = get_data()
                print(bottom_l, bottom_r, "|", front_l, front_r)

                if frontsensor and (front_l > threshold or front_r > threshold) if not obstacle_detected else \
                                   (front_l < threshold and front_r < threshold):
                    if frontsensor == 1:
                        raise KeyboardInterrupt
                    elif frontsensor == 2:
                        turnspd *= -1
                        forwardspd *= -1
                        obstacle_detected = not obstacle_detected

                if bottom_l > threshold and bottom_r > threshold:  # both black
                    if drive_mode != 0:
                        drive(max_speed, forwardspd, read_z(), k_p, k_d, k_i, accuracy)
                        drive_mode = 0
                        print("> go forward")
                    if stopline_detected:
                        raise KeyboardInterrupt
                elif bottom_l < threshold and bottom_r > threshold:  # left white
                    if drive_mode != 1:
                        drive(turnspd, 0, read_z()-5, k_p, k_d, k_i, accuracy)
                        drive_mode = 1
                        print("> turn right")
                    if stopline_detected:
                        stopline_detected = 0
                elif bottom_l > threshold and bottom_r < threshold:  # right white
                    if drive_mode != 2:
                        drive(turnspd, 0, read_z()+5, k_p, k_d, k_i, accuracy)
                        drive_mode = 2
                        print("> turn left")
                    if stopline_detected:
                        stopline_detected = 0
                else:  # both white
                    stopline_detected += 1
                    print(">> stopline_detected")
                    if stopline_detected >= stopsign // ((forwardspd+1)//2):
                        stopline_detected = 0
                        if turndir == "Left":
                            if drive_mode != 3:
                                drive(turnspd, 0, read_z()+5, k_p, k_d, k_i, accuracy)
                                drive_mode = 3
                                print("> stopline_detected && turn left")
                        elif turndir == "Right":
                            if drive_mode != 4:
                                drive(turnspd, 0, read_z()-5, k_p, k_d, k_i, accuracy)
                                drive_mode = 4
                                print("> stopline_detected && turn right")
                        elif turndir == "None":
                            if drive_mode != 5:
                                drive(max_speed, turnspd, read_z(), k_p, k_d, k_i, accuracy)
                                drive_mode = 5
                                print("> stopline_detected && go forward")
                        else:
                            raise KeyboardInterrupt
        except KeyboardInterrupt:
            self.zumi.stop()
            print("-- a stop sign found --")

    def turn_to_dir(self, threshold=95, desired_angle=90, speed=[5, -5], motordiff=13, trust_line=True):
        """ desired_angle > 0 -> turn left
            desired_angle < 0 -> turn right
        """
        get_data = self.zumi.get_all_IR_data
        ctrl_motors = self.zumi.control_motors
        read_z = self.zumi.read_z_angle

        def set_motors(left, right):
            ctrl_motors(right, left)

        self.zumi.reset_drive()

        speed_l = [speed[0]+abs(motordiff)*(1 if speed[0] > 0 else -1 if speed[0] < 0 else 0),
                   speed[1]+abs(motordiff)*(1 if speed[1] > 0 else -1 if speed[1] < 0 else 0)]

        before = read_z()

        if desired_angle > 0:
            set_motors(speed_l[1], speed[0])  # turn left
            print("> turn left")
        elif desired_angle < 0:
            set_motors(speed_l[0], speed[1])  # turn right
            print("> turn right")
        else:
            print("> not move")

        try:
            current = before
            while True:
                if trust_line:
                    _, bottom_r, _, bottom_l, _, _ = get_data()
                    print(bottom_l, bottom_r)

                current = read_z()
                gap = ((before+desired_angle)-current) * (-1 if desired_angle < 0 else 1)
                if trust_line and 0 < gap < 10:
                    if bottom_l >= threshold or bottom_r >= threshold:
                        print("stop line detected | abort before the setted angle is reached")
                        break
                elif gap <= 0:
                    if not trust_line or bottom_l >= threshold or bottom_r >= threshold:
                        print("stop line detected | abort after reaching setted angle")
                        break

            print("-- result : %d -> %d -- (%d)" % (before, current, current-before))
        except KeyboardInterrupt:
            print("-- a stop sign found --")
        finally:
            self.zumi.stop()

    def run_courseA(self, reverse_on=False, trust_line=True, senario=False,
                    forwardspd=2, turnspd=[2, 0], motordiff=6, angle_calib=-10):
        """ 색상 카드를 읽어 해당 색상에 맞는 주차공간을 찾아 주차 (주차공간의 전면에 색상카드가 세워질 예정 - 전면카메라를 이용한 색깔 인식): 최대 +80점
            출발 직전 도 레 미 음성 출력 후 출발: +10점
            색깔 인식 후 Zumi 화면에 해당 색상 표시: +20점
            알맞은 주차 공간에 들어갔을 경우 (주차 시간은 1초로 특정함) : +20점
            들어간 주차 공간에서 무사히 빠져나왔을 경우: +30점
            목표 주차 공간을 제외한 다른 주차 공간 진입시 점수 없음
        """
        self.screen.draw_text_center("- course A -")

        # before the zumi start
        self.trace_line(forwardspd=1, turnspd=[1, 0], turndir="None")
        input("[ZUMI] Press enter to start! : ")
        self.play_DoReMi()
        result = self.restricted_color_detector()  # self.color_detector(self.knn_parking)
        order = ["O", "Y", "B"] if senario else [-90-angle_calib, 90+angle_calib, -90-angle_calib]

        # for loop until zumi ever parked
        found = False
        for i, dir in enumerate(order):
            # go until the stop line
            if trust_line:
                self.trace_line(turndir="None", forwardspd=forwardspd, turnspd=turnspd, motordiff=motordiff)
            else:
                self.trace_line(forwardspd=forwardspd, turnspd=turnspd, motordiff=motordiff)
                # go a little bit more
                self.zumi.forward(speed=10, duration=0.3)

            if senario and order[i] not in result:
                continue

            if not found:
                # turn to direction
                self.turn_to_dir(desired_angle=dir, speed=[1, -1])

                if senario or self.restricted_color_detector() == result:
                    # park
                    self.trace_line()
                    time.sleep(1)

                    # pull out
                    if reverse_on:
                        self.zumi.reverse(speed=10, duration=0.5)
                        self.trace_line(forwardspd=-10, turnspd=[-5, 1])
                    else:
                        self.turn_to_dir(desired_angle=dir*-2, speed=[1, -1])
                        self.trace_line()
                        # go a little bit more
                        self.zumi.forward(speed=10, duration=0.3)
                    found = True
                    print("zumi found the parkig lot!")

                # turn to direction
                self.turn_to_dir(desired_angle=dir * (-1 if (reverse_on or not found) else 1))

    def run_courseB(self, turnspd=[2, 0], forwardspd=2, motordiff=0):
        """ 빨강색 Color Card 를 이용해 B course 시작지점에 정차했다가 카드를 치우면 남은 B course를 올바르게 주행하는지: 최대 +50점
            빨간색 카드를 제대로 인식하고 정지하는지: 각 +15점 (빨간색 카드는 총 2회 등장함: 총 +30점)
            초록색 카드를 제대로 인식하고 빨간색 카드가 없을 때 올바르게 주행하는지: +20점
            힌트: 앞에 장애물이 있을때 색깔 카드를 인식하도록 하면 더욱 좋은 정확도를 가질수 있음
        """
        self.screen.draw_text_center("- course B -")

        # go forward
        self.trace_line(forwardspd=4, turndir="None")

        # detect red light
        while self.color_detector(self.knn_trafficlight) != "Red":
            pass
        print("red light is detected")
        while self.color_detector(self.knn_trafficlight, len=3) == "Red":
            pass
        print("red light was removed")

        # go until the stop line
        self.trace_line(turnspd=turnspd, forwardspd=forwardspd, turndir="None", motordiff=motordiff)

    def run_courseC(self, backandforth=0, threshold=[40, 120]):
        """ 신호등의 색상이 초록색으로 바뀌면 QR코드를 인식하고 QR코드 문제를 올바르게 해결하여 적절한 도착지점에 도착: 최대 +70점
            QR코드 지점까지 올바르게 라인트레이싱: +10점
            QR코드의 message를 올바르게 인식: +10점
            message속의 수식을 eval을 이용하여 정답을 구한 뒤 Zumi에 정답을 띄울시: +10점
            정답을 활용하여 올바른 종료지점에 도착: +20점
            (단 최종 도착지점은 QR문제 별로 다를것, 단순히 방향으로 도착지점에 도착하는 경우를 방지하기 위함)
            모든 주행 종료 후 주미의 표정이 웃고있는것: +10점
            모든 주행 종료 후 주미가 춤을 추기: +10점
            (표정은 자신이 만든 간단히 웃는 표정을 만들어야합니다. 눈만 있으면 인정, personality 라이브러리 사용 금지, screen 라이브러리 허용)
            (춤의 예 : 간단하게 Zumi가 5바퀴를 회전. )
        """
        self.screen.draw_text_center("- course C -")

        # detect red light
        while self.color_detector(self.knn_trafficlight, len=3) != "Red":
            pass

        # detect green light
        while self.color_detector(self.knn_trafficlight, len=3) != "Green":
            pass

        # go until the stop line
        self.trace_line(turndir="None", forwardspd=4, turnspd=[2, 0], motordiff=6)

        # detect QR
        result = None
        reversed = 0
        while True:
            result = self.qr_detector()
            if result is not None:
                if reversed:
                    self.zumi.forward(speed=10, duration=reversed)
                break
            elif backandforth:  # maybe not working
                #self.trace_line(frontsensor=2, duration=1)
                if not reversed:
                    self.zumi.reverse(speed=10, duration=backandforth)
                    reversed = backandforth
                else:
                    self.zumi.forward(speed=10, duration=1)
                    reversed = 1 if reversed == 2 else 0

        # go until jumi reaches the junction
        self.trace_line(duration=1)

        # turn
        self.turn_to_dir(desired_angle=90 if 'L' in result else -90)

        # end
        self.trace_line(frontsensor=1, forwardspd=4, turnspd=[2, 0],
                        turndir="Right" if 'L' in result else "Left", threshold=threshold)
        self.print_face()
        self.play_NextLevel()

# %%
from FATI_Main import TeamOverload; fati = TeamOverload()
# Out:
# Starting Zumi
# Pi Zero I2C is available
# Verified Pi Zero is the same
# Gyroscope previously calibrated
# Zumi board detected
# OLED Screen detected
# Gyroscope & Accelerometer detected
# Loaded  Parking_1500_8444  successfully
# Loaded  All_400_8444  successfully
# Starting PiCamera

# %%
# init
fati = TeamOverload()
# Out:
# Starting Zumi
# Pi Zero I2C is available
# Verified Pi Zero is the same
# Gyroscope previously calibrated
# Zumi board detected
# OLED Screen detected
# Gyroscope & Accelerometer detected
# Loaded  Parking_1500_8444  successfully
# Loaded  All_400_8444  successfully
# Starting PiCamera

# %%
# course A
fati.run_courseA()
# Out:
# 154 121 | 162 67
# > go forward
# 154 121 | 162 67
# > go forward
# 158 117 | 155 63
# > go forward
# 158 117 | 155 63
# > go forward
# 156 125 | 157 61
# > go forward
# 150 130 | 160 64
# > go forward
# 153 130 | 158 64
# > go forward
# 154 134 | 158 65
# > go forward
# 149 134 | 156 61
# > go forward
# 149 134 | 156 61
# > go forward
# 127 140 | 163 66
# > go forward
# 97 140 | 157 65
# > go forward
# 16 146 | 156 63
# > turn right
# 15 147 | 156 66
# > turn right
# 15 147 | 156 66
# > turn right
# 14 148 | 156 67
# > turn right
# 16 146 | 157 64
# > turn right
# 39 147 | 158 63
# > turn right
# 107 143 | 160 63
# > go forward
# 135 148 | 161 63
# > go forward
# 137 133 | 168 112
# > go forward
# 137 133 | 168 112
# > go forward
# 149 50 | 164 65
# > turn left
# 152 28 | 163 67
# > turn left
# 154 23 | 164 64
# > turn left
# 150 75 | 164 65
# > turn left
# 149 130 | 165 68
# > go forward
# 133 132 | 158 65
# > go forward
# 60 131 | 156 64
# > turn right
# 60 131 | 156 64
# > turn right
# 20 139 | 156 69
# > turn right
# 17 141 | 162 70
# > turn right
# 31 139 | 157 65
# > turn right
# 83 140 | 158 65
# > turn right
# 132 136 | 159 64
# > go forward
# 122 129 | 160 65
# > go forward
# 28 70 | 159 66
# >> stopline_detected
# 28 70 | 159 66
# >> stopline_detected
# 14 12 | 163 66
# >> stopline_detected
# 13 12 | 166 66
# >> stopline_detected
# 14 13 | 162 67
# >> stopline_detected
# 14 13 | 162 67
# >> stopline_detected
# 14 13 | 162 67
# >> stopline_detected
# 14 14 | 161 62
# >> stopline_detected
# 20 12 | 168 67
# >> stopline_detected
# 20 12 | 168 67
# >> stopline_detected
# 141 12 | 165 67
# > turn left
# 148 13 | 163 65
# > turn left
# 150 15 | 162 64
# > turn left
# 142 127 | 161 66
# > go forward
# -- a stop sign found --
# [ZUMI] Press enter to start! :
# ['Yellow', 'Yellow', 'Yellow', 'Yellow', 'Yellow']
# color_detector result : Yellow
# 19 13 | 171 78
# >> stopline_detected
# 19 13 | 171 78
# >> stopline_detected
# 18 13 | 170 80
# >> stopline_detected
# 18 13 | 170 80
# >> stopline_detected
# 18 13 | 171 80
# >> stopline_detected
# 18 13 | 171 80
# >> stopline_detected
# 18 13 | 170 80
# >> stopline_detected
# > stopline_detected && go forward
# 18 13 | 170 78
# >> stopline_detected
# > stopline_detected && go forward
# 19 12 | 173 77
# >> stopline_detected
# > stopline_detected && go forward
# 80 46 | 167 72
# >> stopline_detected
# > stopline_detected && go forward
# 142 137 | 168 75
# > go forward
# -- a stop sign found --
# > turn right
# 137 137
# 151 139
# 151 139
# 154 125
# 146 15
# 143 14
# 143 14
# 93 14
# 19 18
# 19 18
# 19 12
# 19 12
# 17 13
# 16 15
# 16 13
# 16 12
# 14 13
# 14 13
# 14 12
# 14 14
# 14 14
# 15 12
# 15 12
# 14 12
# 14 13
# 14 13
# 14 14
# 14 12
# 16 13
# 16 13
# 14 13
# 14 13
# 14 14
# 15 12
# 15 12
# 15 12
# 15 12
# 15 12
# 14 15
# 14 15
# 14 15
# 15 14
# 32 13
# 13 14
# 13 14
# 13 14
# 13 123
# -- result : 0 -> -356 --
# ['Orange', 'Blue', 'Blue', 'Blue', 'Blue']
# color_detector result : Blue
# > turn left
# 150 140
# 136 139
# 136 139
# 55 131
# 17 129
# 17 129
# 14 91
# 15 14
# 17 13
# 17 14
# 16 14
# 14 15
# 14 15
# 16 14
# 15 13
# 14 13
# 14 13
# 13 14
# 13 14
# 14 14
# 15 12
# 15 13
# 14 13
# 14 13
# 14 13
# 14 14
# 14 13
# 14 12
# 14 13
# 14 13
# 14 14
# 15 14
# 17 13
# 15 13
# 15 13
# 15 13
# 15 13
# 15 13
# 15 13
# 22 13
# 80 13
# 146 14
# -- result : -359 -> 4 --
# 19 131 | 160 71
# > turn right
# 19 131 | 160 71
# > turn right
# 15 131 | 156 67
# > turn right
# 15 134 | 156 96
# > turn right
# 15 139 | 156 68
# > turn right
# 17 142 | 162 70
# > turn right
# 17 142 | 162 70
# > turn right
# 14 141 | 158 69
# > turn right
# 15 145 | 157 68
# > turn right
# 22 145 | 158 65
# > turn right
# 63 148 | 159 65
# > turn right
# 123 149 | 160 64
# > go forward
# 148 142 | 160 63
# > go forward
# 148 142 | 160 63
# > go forward
# 141 127 | 164 65
# > go forward
# 151 135 | 162 67
# > go forward
# 151 135 | 162 67
# > go forward
# 149 135 | 160 61
# > go forward
# 135 140 | 166 66
# > go forward
# 102 143 | 160 66
# > go forward
# 50 143 | 158 65
# > turn right
# 16 146 | 158 68
# > turn right
# 16 146 | 158 68
# > turn right
# 15 144 | 157 67
# > turn right
# 38 145 | 161 96
# > turn right
# 91 147 | 160 65
# > turn right
# 91 147 | 160 65
# > turn right
# 130 146 | 162 65
# > go forward
# 134 143 | 167 66
# > go forward
# 134 143 | 167 66
# > go forward
# 134 143 | 167 66
# > go forward
# 134 143 | 167 66
# > go forward
# 155 72 | 167 63
# > turn left
# 155 72 | 167 63
# > turn left
# 146 131 | 160 66
# > go forward
# 146 131 | 160 66
# > go forward
# 129 131 | 157 61
# > go forward
# 52 133 | 158 63
# > turn right
# 17 128 | 156 67
# > turn right
# 15 14 | 157 66
# >> stopline_detected
# 15 14 | 157 66
# >> stopline_detected
# 14 13 | 157 66
# >> stopline_detected
# 14 13 | 157 66
# >> stopline_detected
# 14 13 | 157 65
# >> stopline_detected
# 16 13 | 163 68
# >> stopline_detected
# 16 13 | 163 68
# >> stopline_detected
# > stopline_detected && go forward
# 14 13 | 159 63
# >> stopline_detected
# > stopline_detected && go forward
# 14 14 | 160 65
# >> stopline_detected
# > stopline_detected && go forward
# 14 14 | 157 65
# >> stopline_detected
# > stopline_detected && go forward
# 16 12 | 159 61
# >> stopline_detected
# > stopline_detected && go forward
# 15 12 | 162 63
# >> stopline_detected
# > stopline_detected && go forward
# 21 14 | 160 65
# >> stopline_detected
# > stopline_detected && go forward
# 59 133 | 158 62
# > turn right
# 59 133 | 158 62
# > turn right
# 16 142 | 158 65
# > turn right
# 15 138 | 158 65
# > turn right
# 15 140 | 162 67
# > turn right
# 30 138 | 159 63
# > turn right
# 83 138 | 159 63
# > turn right
# 83 138 | 168 63
# > turn right
# 126 137 | 161 63
# > go forward
# -- a stop sign found --
# > turn left
# 139 118
# 140 104
# -- a stop sign found --
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
#
# KeyboardInterrupt

# %%
# course B
fati.run_courseB()

# %%
# course C
fati.run_courseC()
# Out:
# 129 152 | 176 84
# > go forward
# 130 150 | 174 78
# > go forward
# 122 142 | 174 82
# > go forward
# 98 144 | 173 77
# > go forward
# 98 144 | 173 77
# > go forward
# 65 152 | 169 83
# > turn right
# 65 152 | 169 83
# > turn right
# 25 151 | 172 80
# > turn right
# 48 153 | 171 79
# > turn right
# 115 152 | 176 82
# > go forward
# 138 140 | 169 72
# > go forward
# 138 140 | 169 72
# > go forward
# 148 15 | 169 76
# > turn left
# 148 15 | 169 76
# > turn left
# 154 13 | 172 78
# > turn left
# 153 13 | 170 77
# > turn left
# 154 14 | 171 80
# > turn left
# 152 87 | 173 76
# > turn left
# 140 150 | 176 82
# > go forward
# 129 151 | 183 110
# > go forward
# 133 152 | 175 85
# > go forward
# 133 145 | 175 81
# > go forward
# 141 31 | 173 85
# time out
# -- a stop sign found --
# > turn left
# 138 14
# 134 13
# 151 13
# 159 15
# 159 57
# 155 136
# 155 136
# 69 144
# 17 143
# 13 65
# 14 15
# 14 15
# 16 13
# 15 14
# 15 14
# 15 14
# 15 14
# 17 15
# 28 14
# 42 12
# 42 12
# 149 12
# -- result : 22 -> 208 --
# 151 131 | 159 75
# > go forward
# 124 145 | 168 82
# > go forward
# 25 144 | 166 79
# > turn right
# 16 88 | 168 77
# > turn right
# 15 15 | 170 78
# >> stopline_detected
# 15 14 | 173 78
# >> stopline_detected
# 15 14 | 173 78
# >> stopline_detected
# > stopline_detected && turn right
# 15 14 | 169 79
# >> stopline_detected
# > stopline_detected && turn right
# 15 14 | 166 78
# >> stopline_detected
# > stopline_detected && turn right
# 15 14 | 164 78
# >> stopline_detected
# > stopline_detected && turn right
# 15 13 | 167 80
# >> stopline_detected
# > stopline_detected && turn right
# 15 14 | 160 74
# >> stopline_detected
# > stopline_detected && turn right
# 15 14 | 159 74
# >> stopline_detected
# > stopline_detected && turn right
# 15 14 | 159 74
# >> stopline_detected
# > stopline_detected && turn right
# 14 13 | 156 69
# >> stopline_detected
# > stopline_detected && turn right
# 12 12 | 154 66
# >> stopline_detected
# > stopline_detected && turn right
# 34 115 | 157 61
# > turn right
# 86 28 | 166 67
# > turn left
# 38 31 | 170 82
# >> stopline_detected
# 38 31 | 170 82
# >> stopline_detected
# 43 49 | 178 83
# > go forward
# 47 77 | 178 85
# > go forward
# 12 43 | 173 83
# > turn right
# 12 43 | 173 83
# > turn right
# 13 135 | 172 81
# > turn right
# 25 148 | 172 82
# > turn right
# 25 148 | 172 82
# > turn right
# 25 147 | 172 82
# > turn right
# 33 150 | 172 82
# > turn right
# 47 147 | 172 83
# > go forward
# 48 148 | 170 85
# > go forward
# 41 149 | 172 80
# > go forward
# 41 149 | 172 80
# > go forward
# 41 149 | 172 80
# > go forward
# 64 143 | 178 82
# > go forward
# 98 145 | 173 79
# > go forward
# 98 145 | 173 79
# > go forward
# 104 148 | 172 85
# > go forward
# 92 149 | 174 110
# > go forward
# 92 149 | 174 110
# > go forward
# 26 136 | 173 81
# > turn right
# 18 134 | 173 83
# > turn right
# 17 145 | 173 83
# > turn right
# 15 148 | 173 83
# > turn right
# 15 148 | 173 83
# > turn right
# 22 137 | 176 84
# > turn right
# 64 148 | 175 84
# > go forward
# 104 146 | 175 85
# > go forward
# 114 148 | 175 80
# > go forward
# 79 136 | 178 84
# > go forward
# 14 147 | 176 87
# > turn right
# 14 147 | 176 87
# > turn right
# 14 149 | 175 84
# > turn right
# 15 147 | 175 83
# > turn right
# 15 150 | 180 86
# > turn right
# 14 147 | 176 84
# > turn right
# 14 147 | 176 84
# > turn right
# 18 146 | 176 85
# > turn right
# 74 148 | 176 85
# > go forward
# 132 146 | 176 85
# > go forward
# 134 140 | 179 84
# > go forward
# 140 121 | 178 86
# > go forward
# 142 107 | 177 83
# > go forward
# 142 107 | 177 83
# > go forward
# 148 125 | 174 85
# > go forward
# 139 133 | 176 83
# > go forward
# 141 141 | 180 83
# > go forward
# 131 136 | 176 87
# > go forward
# 105 139 | 174 81
# > go forward
# 52 146 | 174 81
# > go forward
# 15 143 | 176 83
# > turn right
# 14 138 | 176 85
# > turn right
# 14 138 | 176 85
# > turn right
# 14 133 | 175 84
# > turn right
# 15 137 | 175 85
# > turn right
# 27 139 | 175 85
# > turn right
# 27 146 | 175 88
# > turn right
# 95 146 | 181 88
# > go forward
# 145 126 | 176 80
# > go forward
# 145 126 | 176 80
# > go forward
# 147 88 | 172 86
# > go forward
# 153 48 | 175 81
# > go forward
# 150 25 | 176 83
# > turn left
# 143 14 | 180 107
# > turn left
# 149 124 | 181 83
# > go forward
# 149 124 | 181 83
# > go forward
# 128 139 | 173 85
# > go forward
# 34 142 | 184 149
# > turn right
# 15 148 | 179 88
# > turn right
# 14 147 | 174 85
# > turn right
# 14 149 | 175 84
# > turn right
# 15 149 | 175 84
# > turn right
# 19 147 | 176 85
# > turn right
# 63 148 | 175 84
# > go forward
# 116 149 | 177 87
# > go forward
# 127 140 | 176 81
# > go forward
# 127 140 | 176 81
# > go forward
# 134 140 | 173 87
# > go forward
# 137 145 | 182 88
# > go forward
# 138 138 | 178 85
# > go forward
# 138 138 | 178 85
# > go forward
# 134 140 | 174 88
# > go forward
# 133 143 | 174 82
# > go forward
# 118 147 | 176 84
# > go forward
# 93 155 | 177 85
# > go forward
# 62 153 | 176 84
# > go forward
# 35 156 | 175 82
# > turn right
# 20 155 | 177 85
# > turn right
# 22 154 | 176 84
# > turn right
# 22 154 | 176 84
# > turn right
# 39 155 | 181 88
# > turn right
# 104 152 | 176 85
# > go forward
# 136 148 | 175 81
# > go forward
# 131 139 | 174 79
# > go forward
# 137 120 | 174 85
# > go forward
# 132 87 | 176 83
# > go forward
# 132 61 | 176 84
# > go forward
# 138 50 | 176 85
# > go forward
# 142 42 | 174 81
# > go forward
# 142 40 | 174 83
# > go forward
# 142 40 | 174 83
# > go forward
# 90 46 | 182 87
# > go forward
# 90 46 | 182 87
# > go forward
# 90 46 | 182 87
# > go forward
# 90 46 | 182 87
# > go forward
# 16 15 | 174 82
# >> stopline_detected
# 16 15 | 174 82
# >> stopline_detected
# 16 14 | 87 14
# obstacle detected
# -- a stop sign found --

# %%
# course A
fati.run_courseA()

# course B
fati.run_courseB()

# course C
fati.run_courseC()
# Out:
# 16 43 | 178 87
# >> stopline_detected
# 16 44 | 178 86
# >> stopline_detected
# 16 44 | 178 86
# >> stopline_detected
# 16 43 | 178 86
# >> stopline_detected
# 16 45 | 178 87
# >> stopline_detected
# 16 45 | 178 87
# >> stopline_detected
# 16 44 | 178 86
# >> stopline_detected
# 16 44 | 178 86
# >> stopline_detected
# 16 44 | 178 86
# >> stopline_detected
# 16 44 | 178 86
# >> stopline_detected
# 16 44 | 178 86
# >> stopline_detected
# 16 44 | 178 86
# >> stopline_detected
# 16 44 | 178 87
# >> stopline_detected
# 16 44 | 178 87
# >> stopline_detected
# 16 43 | 177 86
# >> stopline_detected
# > stopline_detected && go forward
# 16 43 | 177 86
# >> stopline_detected
# > stopline_detected && go forward
# 16 35 | 170 84
# >> stopline_detected
# > stopline_detected && go forward
# 14 13 | 172 81
# >> stopline_detected
# > stopline_detected && go forward
# 15 13 | 176 82
# >> stopline_detected
# > stopline_detected && go forward
# 17 12 | 177 82
# >> stopline_detected
# > stopline_detected && go forward
# 17 12 | 177 82
# >> stopline_detected
# > stopline_detected && go forward
# 16 14 | 172 83
# >> stopline_detected
# > stopline_detected && go forward
# 15 13 | 174 79
# >> stopline_detected
# > stopline_detected && go forward
# 13 13 | 174 82
# >> stopline_detected
# > stopline_detected && go forward
# 14 14 | 175 84
# >> stopline_detected
# > stopline_detected && go forward
# 14 14 | 175 84
# >> stopline_detected
# > stopline_detected && go forward
# 14 14 | 175 84
# >> stopline_detected
# > stopline_detected && go forward
# 15 13 | 174 81
# >> stopline_detected
# > stopline_detected && go forward
# 15 13 | 175 82
# >> stopline_detected
# > stopline_detected && go forward
# 14 14 | 173 81
# >> stopline_detected
# > stopline_detected && go forward
# 14 14 | 173 81
# >> stopline_detected
# > stopline_detected && go forward
# 16 14 | 171 83
# >> stopline_detected
# > stopline_detected && go forward
# 15 12 | 174 79
# >> stopline_detected
# > stopline_detected && go forward
# 15 12 | 174 79
# >> stopline_detected
# > stopline_detected && go forward
# 14 13 | 175 82
# >> stopline_detected
# > stopline_detected && go forward
# 15 15 | 175 129
# >> stopline_detected
# > stopline_detected && go forward
# 14 15 | 173 79
# >> stopline_detected
# > stopline_detected && go forward
# 16 14 | 172 82
# >> stopline_detected
# > stopline_detected && go forward
# 14 13 | 175 81
# >> stopline_detected
# > stopline_detected && go forward
# 13 13 | 173 81
# >> stopline_detected
# > stopline_detected && go forward
# 16 13 | 174 84
# >> stopline_detected
# > stopline_detected && go forward
# 14 14 | 172 79
# >> stopline_detected
# > stopline_detected && go forward
# 14 14 | 172 79
# >> stopline_detected
# > stopline_detected && go forward
# 14 14 | 171 81
# >> stopline_detected
# > stopline_detected && go forward
# 16 13 | 174 81
# >> stopline_detected
# > stopline_detected && go forward
# 14 14 | 174 82
# >> stopline_detected
# > stopline_detected && go forward
# 14 14 | 170 83
# >> stopline_detected
# > stopline_detected && go forward
# 14 14 | 170 83
# >> stopline_detected
# > stopline_detected && go forward
# 15 12 | 171 79
# >> stopline_detected
# > stopline_detected && go forward
# 15 13 | 174 81
# >> stopline_detected
# > stopline_detected && go forward
# 14 12 | 174 81
# >> stopline_detected
# > stopline_detected && go forward
# 14 12 | 171 83
# >> stopline_detected
# > stopline_detected && go forward
# 13 15 | 171 78
# >> stopline_detected
# > stopline_detected && go forward
# 11 12 | 169 83
# >> stopline_detected
# > stopline_detected && go forward
# 13 12 | 171 73
# >> stopline_detected
# > stopline_detected && go forward
# 13 12 | 171 73
# >> stopline_detected
# > stopline_detected && go forward
# 76 66 | 164 66
# >> stopline_detected
# > stopline_detected && go forward
# 80 71 | 160 67
# >> stopline_detected
# > stopline_detected && go forward
# 97 86 | 158 62
# > turn left
# 76 66 | 160 65
# >> stopline_detected
# > stopline_detected && go forward
# 91 69 | 163 69
# >> stopline_detected
# > stopline_detected && go forward
# 132 77 | 162 66
# > turn left
# 132 77 | 162 66
# > turn left
# 139 84 | 163 67
# > turn left
# 153 111 | 159 68
# > go forward
# -- a stop sign found --
# [ZUMI] Press enter to start! :
# ['Yellow', 'Yellow', 'Yellow', 'Yellow', 'Yellow']
# color_detector result : Yellow
# 148 139 | 173 81
# > go forward
# 148 139 | 173 82
# > go forward
# 143 135 | 170 75
# > go forward
# 134 137 | 168 76
# > go forward
# 134 137 | 168 76
# > go forward
# 54 134 | 165 79
# > turn right
# 17 136 | 167 77
# > turn right
# 15 140 | 166 76
# > turn right
# 15 141 | 166 77
# > turn right
# 15 141 | 166 77
# > turn right
# 15 141 | 166 76
# > turn right
# 14 142 | 167 77
# > turn right
# 17 144 | 173 78
# > turn right
# 14 141 | 167 78
# > turn right
# 14 142 | 168 78
# > turn right
# 14 144 | 168 79
# > turn right
# 14 144 | 168 79
# > turn right
# 14 142 | 167 78
# > turn right
# 14 142 | 167 78
# > turn right
# 14 143 | 167 78
# > turn right
# 14 144 | 167 79
# > turn right
# 15 147 | 174 82
# > turn right
# 14 143 | 166 78
# > turn right
# 14 143 | 166 78
# > turn right
# 14 143 | 166 78
# > turn right
# 14 143 | 167 79
# > turn right
# 14 143 | 174 112
# > turn right
# 14 143 | 167 79
# > turn right
# 14 143 | 167 79
# > turn right
# 14 144 | 167 79
# > turn right
# 14 144 | 167 79
# > turn right
# 15 145 | 167 81
# > turn right
# 14 144 | 167 79
# > turn right
# 15 147 | 175 82
# > turn right
# 14 144 | 168 81
# > turn right
# 14 144 | 168 81
# > turn right
# 14 143 | 168 79
# > turn right
# 14 143 | 168 79
# > turn right
# 14 144 | 168 81
# > turn right
# 14 145 | 170 81
# > turn right
# 14 144 | 169 82
# > turn right
# 14 144 | 170 81
# > turn right
# 14 144 | 170 81
# > turn right
# 14 144 | 171 81
# > turn right
# 15 147 | 178 83
# > turn right
# 14 144 | 171 79
# > turn right
# 14 144 | 170 78
# > turn right
# 14 145 | 170 76
# > turn right
# 14 145 | 170 76
# > turn right
# 14 145 | 167 75
# > turn right
# 14 144 | 165 75
# > turn right
# 14 144 | 164 72
# > turn right
# 14 143 | 164 73
# > turn right
# 13 113 | 164 74
# > turn right
# 14 115 | 181 73
# > turn right
# 53 122 | 171 76
# > turn right
# 101 128 | 165 73
# > go forward
# 126 128 | 168 75
# > go forward
# 133 123 | 171 75
# > go forward
# 133 123 | 171 75
# > go forward
# 133 123 | 171 75
# > go forward
# 140 122 | 167 73
# > go forward
# 135 120 | 172 72
# > go forward
# 130 107 | 173 74
# > go forward
# 130 107 | 173 74
# > go forward
# 147 137 | 167 74
# > go forward
# 147 137 | 167 74
# > go forward
# 136 147 | 175 77
# > go forward
# 131 142 | 171 72
# > go forward
# 131 142 | 171 72
# > go forward
# 51 141 | 168 73
# > turn right
# 51 141 | 168 73
# > turn right
# 18 148 | 169 75
# > turn right
# 16 146 | 172 75
# > turn right
# 24 147 | 171 76
# > turn right
# 61 147 | 172 76
# > turn right
# 113 147 | 172 75
# > go forward
# 134 147 | 173 78
# > go forward
# 131 142 | 179 79
# > go forward
# 131 142 | 179 79
# > go forward
# 131 142 | 179 79
# > go forward
# 131 142 | 179 79
# > go forward
# 141 137 | 172 82
# > go forward
# 140 139 | 172 78
# > go forward
# 131 139 | 172 81
# > go forward
# 94 139 | 176 79
# > turn right
# 45 138 | 174 82
# > turn right
# 26 139 | 174 83
# > turn right
# 26 139 | 174 83
# > turn right
# 33 136 | 174 83
# > turn right
# 76 135 | 174 81
# > turn right
# 102 126 | 174 81
# > go forward
# 22 51 | 177 79
# >> stopline_detected
# 22 51 | 177 79
# >> stopline_detected
# 14 14 | 175 86
# >> stopline_detected
# 14 14 | 171 76
# >> stopline_detected
# 14 13 | 168 79
# >> stopline_detected
# 14 13 | 168 79
# >> stopline_detected
# 14 12 | 171 76
# >> stopline_detected
# > stopline_detected && go forward
# 14 12 | 171 76
# >> stopline_detected
# > stopline_detected && go forward
# 14 12 | 171 76
# >> stopline_detected
# > stopline_detected && go forward
# 105 84 | 169 80
# > turn left
# 105 84 | 169 80
# > turn left
# 110 138 | 173 76
# > go forward
# -- a stop sign found --
# > turn right
# 14 144
# 14 144
# 14 144
# 14 144
# 14 144
# 14 144
# 14 144
# 68 15
# 68 15
# 68 15
# 68 15
# 68 15
# 15 14
# 14 21
# 14 15
# 16 14
# 16 14
# 16 13
# 15 14
# 15 14
# 13 14
# 14 15
# 14 15
# 15 15
# 14 119
# -- result : 2 -> -156 --
# ['Blue', 'Orange', 'Orange', 'Orange', 'Orange']
# color_detector result : Orange
# > turn left
# 146 123
# 150 127
# 137 137
# 137 137
# 32 134
# 14 130
# 15 20
# 14 15
# 15 12
# 15 12
# 15 13
# 129 14
# -- result : -158 -> -56 --
# 150 106 | 170 70
# > go forward
# 118 134 | 166 76
# > go forward
# 118 137 | 166 74
# > go forward
# 20 137 | 172 74
# > turn right
# 13 135 | 169 76
# > turn right
# 15 126 | 173 80
# > turn right
# 15 126 | 173 80
# > turn right
# 15 114 | 168 75
# > turn right
# 14 126 | 168 75
# > turn right
# 15 133 | 167 74
# > turn right
# 14 135 | 168 74
# > turn right
# 14 135 | 168 74
# > turn right
# 15 135 | 169 73
# > turn right
# 29 136 | 169 75
# > turn right
# 83 144 | 171 75
# > turn right
# 129 139 | 170 76
# > go forward
# 142 134 | 173 76
# > go forward
# 142 134 | 173 76
# > go forward
# 141 116 | 166 79
# > go forward
# 145 96 | 171 76
# > go forward
# 139 81 | 171 77
# > turn left
# 137 104 | 172 81
# > go forward
# 137 104 | 172 81
# > go forward
# 136 129 | 168 71
# > go forward
# 126 139 | 169 75
# > go forward
# 69 140 | 174 76
# > turn right
# 24 141 | 171 75
# > turn right
# 17 144 | 175 78
# > turn right
# 17 144 | 175 78
# > turn right
# 14 144 | 170 75
# > turn right
# 16 144 | 171 75
# > turn right
# 41 146 | 172 77
# > turn right
# 95 144 | 172 76
# > go forward
# 133 142 | 171 94
# > go forward
# 135 136 | 172 72
# > go forward
# 117 128 | 173 78
# > go forward
# 15 13 | 173 75
# >> stopline_detected
# 15 13 | 173 75
# >> stopline_detected
# 15 13 | 173 75
# >> stopline_detected
# 15 13 | 173 75
# >> stopline_detected
# 15 13 | 173 74
# >> stopline_detected
# 13 13 | 174 74
# >> stopline_detected
# 17 12 | 174 78
# >> stopline_detected
# > stopline_detected && go forward
# 14 13 | 169 71
# >> stopline_detected
# > stopline_detected && go forward
# 15 14 | 171 73
# >> stopline_detected
# > stopline_detected && go forward
# 15 145 | 170 74
# > turn right
# 14 144 | 170 74
# > turn right
# 14 144 | 170 74
# > turn right
# 14 145 | 170 73
# > turn right
# 15 143 | 170 71
# > turn right
# 36 147 | 169 67
# > turn right
# 95 144 | 168 65
# > go forward
# -- a stop sign found --
# > turn left
# 137 142
# 144 137
# 144 137
# 108 142
# 14 138
# 13 32
# 13 32
# 14 13
# 15 13
# 14 14
# 18 12
# 18 12
# 17 14
# 24 14
# 30 12
# 142 13
# -- result : -57 -> 67 --
# ['Blue', 'Yellow', 'Yellow', 'Yellow', 'Yellow']
# color_detector result : Yellow
# 137 148 | 174 83
# > go forward
# 138 149 | 174 83
# > go forward
# 136 144 | 171 79
# > go forward
# 124 145 | 172 83
# > go forward
# 91 146 | 171 77
# > turn right
# 91 146 | 171 77
# > turn right
# 52 149 | 170 81
# > turn right
# 61 146 | 169 79
# > turn right
# 108 145 | 173 80
# > go forward
# 135 135 | 170 75
# > go forward
# 141 129 | 168 80
# > go forward
# 141 129 | 168 80
# > go forward
# 149 126 | 167 75
# > go forward
# 149 126 | 167 75
# > go forward
# 145 123 | 165 76
# > go forward
# 145 123 | 165 76
# > go forward
# 144 124 | 163 71
# > go forward
# 144 135 | 160 69
# > go forward
# 144 135 | 169 69
# > go forward
# 135 138 | 165 72
# > go forward
# 134 136 | 163 67
# > go forward
# 109 138 | 156 67
# > go forward
# 62 137 | 150 55
# > turn right
# 22 137 | 147 54
# > turn right
# 17 137 | 144 51
# > turn right
# 15 14 | 141 47
# >> stopline_detected
# 15 14 | 141 47
# >> stopline_detected
# -- a stop sign found --
# > turn right
# 14 13
# 16 14
# 15 13
# 15 13
# 17 14
# 17 14
# 14 14
# 14 14
# 14 14
# 15 13
# 14 13
# 14 13
# 14 14
# 14 14
# 14 14
# 15 13
# 15 13
# 14 14
# 14 14
# 14 126
# 16 140
# 126 140
# -- result : 66 -> -94 --
# 140 114 | 177 83
# > go forward
# 140 13 | 177 82
# > turn left
# 136 13 | 178 89
# > turn left
# 157 13 | 178 81
# > turn left
# 157 13 | 180 81
# > turn left
# 150 40 | 179 86
# > turn left
# 147 141 | 179 89
# > go forward
# 122 142 | 174 82
# > go forward
# 23 141 | 174 80
# > turn right
# 14 142 | 172 90
# > turn right
# 16 133 | 174 82
# > turn right
# 15 118 | 174 82
# > turn right
# 15 131 | 174 83
# > turn right
# 15 131 | 174 83
# > turn right
# 15 131 | 174 83
# > turn right
# 14 153 | 174 83
# > turn right
# 14 152 | 174 83
# > turn right
# 93 151 | 179 86
# > turn right
# 93 151 | 179 86
# > turn right
# 139 147 | 175 84
# > go forward
# 148 125 | 176 86
# > go forward
# 153 33 | 174 79
# > turn left
# 151 13 | 179 86
# > turn left
# 151 14 | 179 114
# > turn left
# 154 14 | 181 114
# > turn left
# 154 34 | 179 88
# > turn left
# 158 127 | 180 88
# > go forward
# 150 137 | 171 82
# > go forward
# 78 131 | 173 79
# > turn right
# 22 125 | 179 85
# > turn right
# 18 14 | 174 83
# >> stopline_detected
# 18 14 | 174 83
# >> stopline_detected
# -- a stop sign found --
# zumi found the parkig lot!
# > turn left
# 15 13
# 20 13
# 152 12
# 152 12
# 154 110
# 151 131
# -- result : -93 -> -17 --
# 14 39 | 175 81
# >> stopline_detected
# 14 39 | 175 81
# >> stopline_detected
# 14 14 | 174 83
# >> stopline_detected
# 14 14 | 174 83
# >> stopline_detected
# 14 14 | 174 83
# >> stopline_detected
# 14 14 | 174 83
# >> stopline_detected
# 14 14 | 174 80
# >> stopline_detected
# > stopline_detected && go forward
# 14 13 | 171 74
# >> stopline_detected
# > stopline_detected && go forward
# 14 14 | 172 76
# >> stopline_detected
# > stopline_detected && go forward
# 14 14 | 167 76
# >> stopline_detected
# > stopline_detected && go forward
# 15 13 | 168 73
# >> stopline_detected
# > stopline_detected && go forward
# 14 13 | 168 75
# >> stopline_detected
# > stopline_detected && go forward
# 14 14 | 167 78
# >> stopline_detected
# > stopline_detected && go forward
# 15 13 | 166 83
# >> stopline_detected
# > stopline_detected && go forward
# 15 12 | 169 81
# >> stopline_detected
# > stopline_detected && go forward
# 14 12 | 171 80
# >> stopline_detected
# > stopline_detected && go forward
# 20 13 | 156 62
# >> stopline_detected
# > stopline_detected && go forward
# 15 12 | 139 15
# >> stopline_detected
# > stopline_detected && go forward
# 12 11 | 87 57
# >> stopline_detected
# > stopline_detected && go forward
# 13 13 | 137 55
# >> stopline_detected
# > stopline_detected && go forward
# 15 12 | 145 57
# >> stopline_detected
# > stopline_detected && go forward
# 15 12 | 145 57
# >> stopline_detected
# > stopline_detected && go forward
# 15 12 | 145 57
# >> stopline_detected
# > stopline_detected && go forward
# 130 140 | 162 40
# > go forward
# -- a stop sign found --
# 107 152 | 171 70
# > go forward
# 107 150 | 163 63
# > go forward
# 41 147 | 163 60
# > turn right
# 14 145 | 162 26
# > turn right
# 14 146 | 152 69
# > turn right
# 15 147 | 96 76
# > turn right
# 16 151 | 13 77
# > turn right
# 16 151 | 13 77
# > turn right
# 26 157 | 12 80
# > turn right
# 65 156 | 85 78
# > turn right
# 115 157 | 152 78
# > go forward
# 69 115 | 164 80
# > turn right
# 13 14 | 163 76
# >> stopline_detected
# 13 14 | 163 76
# >> stopline_detected
# 14 14 | 165 78
# >> stopline_detected
# > stopline_detected && go forward
# 12 14 | 170 75
# >> stopline_detected
# > stopline_detected && go forward
# 13 15 | 168 80
# >> stopline_detected
# > stopline_detected && go forward
# 15 13 | 169 75
# >> stopline_detected
# > stopline_detected && go forward
# 15 13 | 169 75
# >> stopline_detected
# > stopline_detected && go forward
# 19 12 | 175 81
# >> stopline_detected
# > stopline_detected && go forward
# 152 134 | 164 81
# > go forward
# -- a stop sign found --
# ['Yellow', 'Purple', 'Blue', 'Blue', 'Blue']
# color_detector result : Blue
# ['White', 'White', 'Orange', 'Orange', 'Orange']
# color_detector result : Orange
# ['Orange', 'Orange', 'Green', 'Green', 'Green']
# color_detector result : Green
# ['Green', 'Green', 'Green', 'Green', 'Green']
# color_detector result : Green
# ['Green', 'Green', 'Green', 'Green', 'Green']
# color_detector result : Green
# ['Green', 'Green', 'Green', 'Green', 'Green']
# color_detector result : Green
# ['Green', 'Green', 'Green', 'Green', 'Green']
# color_detector result : Green
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-aa83523bacb3> in <module>
#       3
#       4 # course B
# ----> 5 fati.run_courseB()
#       6
#       7 # course C
#
# <ipython-input-4-656fb1ceaa1d> in run_courseB(self, turnspd, forwardspd, motordiff)
#     445
#     446         # detect red light
# --> 447         while self.color_detector(self.knn_trafficlight) != "Red":
#     448             pass
#     449         print("red light is detected")
#
# <ipython-input-4-656fb1ceaa1d> in color_detector(self, knn, len, unity)
#      60                 image = self.camera.capture()
#      61                 predicts.append(knn.predict(image))
# ---> 62                 self.screen.draw_text_center("%d/%d" % (i, len))
#      63             print(predicts)
#      64             retry = False
#
# ~/Dashboard/user/Overload/My_Projects/Jupyter/zumi/util/screen.py in draw_text_center(self, string, display, image, font_size, clear)
#     841             current_y += text_height
#     842
# --> 843         display.image(image)
#     844         display.display()
#     845
#
# /usr/local/lib/python3.5/dist-packages/Adafruit_SSD1306/SSD1306.py in image(self, image)
#     203                 # Don't use range here as it's a bit slow
#     204                 for bit in [0, 1, 2, 3, 4, 5, 6, 7]:
# --> 205                     bits = bits << 1
#     206                     bits |= 0 if pix[(x, page*8+7-bit)] == 0 else 1
#     207                 # Update buffer byte and increment to next byte.
#
# KeyboardInterrupt:

# %%
# quit
del fati
# Out:
# Closing PiCamera
# ------------- zumi stopped

# %%
# turning test
for i in range(8):
    fati.turn_to_dir(desired_angle=90, speed=[1, -1])
    fati.turn_to_dir(desired_angle=-180, speed=[1, -1])
for i in range(8):
    fati.turn_to_dir(desired_angle=-90, speed=[1, -1])
    fati.turn_to_dir(desired_angle=180, speed=[1, -1])
print("--------------------------------------------------")
input()
for i in range(8):
    fati.turn_to_dir(desired_angle=90, speed=[1, -1], trust_line=False)
    fati.turn_to_dir(desired_angle=-180, speed=[1, -1], trust_line=False)
for i in range(8):
    fati.turn_to_dir(desired_angle=-90, speed=[1, -1], trust_line=False)
    fati.turn_to_dir(desired_angle=180, speed=[1, -1], trust_line=False)
# Out:
# > turn left
# 168 105
# 167 126
# 167 126
# 164 165
# 57 161
# 31 164
# 20 83
# 22 15
# 22 15
# 49 14
# 169 15
# 169 15
# 174 18
# stop line detected | abort after reaching setted angle
# -- result : 0 -> 94 -- (94)
# > turn right
# 21 167
# 21 167
# 25 176
# 32 165
# 122 164
# 165 143
# 170 16
# 166 15
# 64 15
# 27 15
# 27 15
# 27 15
# 25 160
# 25 160
# 31 162
# 165 165
# 168 14
# 168 14
# 99 14
# 24 16
# 24 16
# 28 148
# 32 164
# stop line detected | abort before the setted angle is reached
# -- result : 1 -> -171 -- (-172)
# > turn left
# 164 137
# 165 103
# 165 103
# 144 170
# 144 170
# 27 166
# 22 162
# 22 162
# 24 28
# 173 15
# 172 69
# stop line detected | abort before the setted angle is reached
# -- result : -1 -> 83 -- (85)
# > turn right
# 27 167
# 22 162
# 38 166
# 136 169
# 136 132
# 183 132
# 168 15
# 168 15
# 44 17
# 44 17
# 28 141
# 23 165
# 132 167
# 132 167
# 168 15
# 168 15
# 168 15
# 168 15
# 24 15
# 18 14
# 23 15
# 23 26
# 28 170
# stop line detected | abort before the setted angle is reached
# -- result : 1 -> -172 -- (-173)
# > turn left
# 155 169
# 147 164
# 71 165
# 71 165
# 27 165
# 17 144
# 19 15
# 24 15
# 26 16
# 26 16
# 80 15
# 173 14
# stop line detected | abort before the setted angle is reached
# -- result : -1 -> 82 -- (83)
# > turn right
# 162 170
# 121 166
# 154 169
# 154 169
# 159 160
# 159 160
# 159 160
# 159 160
# 24 16
# 24 16
# 26 15
# 24 105
# 24 105
# 24 105
# 96 165
# 168 152
# 169 15
# 159 15
# 159 15
# 34 16
# 28 15
# 28 15
# 28 17
# 24 14
# 24 14
# 18 52
# 21 169
# stop line detected | abort after reaching setted angle
# -- result : 3 -> -207 -- (-210)
# > turn left
# 165 160
# 168 124
# 166 159
# 114 161
# 24 164
# 29 162
# 26 23
# 26 23
# 20 14
# 26 16
# 24 17
# 24 15
# 70 15
# 70 15
# 169 16
# stop line detected | abort after reaching setted angle
# -- result : -1 -> 112 -- (114)
# > turn right
# 160 169
# 140 164
# 167 165
# 167 165
# 162 100
# 168 15
# 167 17
# 40 15
# 28 15
# 28 15
# 28 15
# 19 14
# 19 14
# 27 14
# 27 14
# 27 14
# 27 14
# 160 159
# 168 55
# 167 17
# 167 17
# 95 15
# 28 15
# 21 20
# 25 164
# stop line detected | abort after reaching setted angle
# -- result : 3 -> -191 -- (-195)
# > turn left
# 162 167
# 162 167
# 170 167
# 117 170
# 31 167
# 26 167
# 24 31
# 24 31
# 28 15
# 168 14
# 172 34
# stop line detected | abort before the setted angle is reached
# -- result : -1 -> 82 -- (84)
# > turn right
# 167 160
# 79 166
# 112 161
# 164 161
# 171 79
# 171 79
# 158 17
# 158 17
# 36 14
# 17 14
# 24 73
# 25 164
# 76 165
# 76 165
# 169 17
# 169 17
# 167 14
# 36 20
# 26 157
# 153 171
# stop line detected | abort before the setted angle is reached
# -- result : 1 -> -168 -- (-170)
# > turn left
# 166 74
# 174 17
# 168 16
# 168 16
# 163 163
# 110 166
# 110 166
# 25 164
# 28 132
# 28 132
# 145 15
# 168 14
# stop line detected | abort before the setted angle is reached
# -- result : -1 -> 81 -- (83)
# > turn right
# 171 113
# 171 113
# 171 113
# 171 113
# 171 113
# 171 113
# 165 14
# 165 14
# 165 14
# 165 14
# 165 14
# 165 14
# 165 14
# 165 14
# 160 17
# 160 17
# 160 17
# 160 17
# 160 17
# 160 17
# 160 17
# 160 17
# 18 169
# 18 169
# stop line detected | abort before the setted angle is reached
# -- result : 1 -> -177 -- (-179)
# > turn left
# 165 15
# 169 19
# 171 16
# 165 21
# 165 21
# 162 151
# 162 151
# 119 166
# 27 135
# 28 15
# 28 15
# 24 15
# 45 14
# 173 15
# stop line detected | abort after reaching setted angle
# -- result : -1 -> 103 -- (104)
# > turn right
# 165 161
# 165 161
# 163 157
# 166 15
# 166 15
# 166 15
# 166 15
# 166 15
# 25 14
# 27 15
# 26 95
# 26 166
# 26 166
# 103 167
# 166 17
# 166 15
# 36 15
# 26 15
# 26 15
# 25 15
# 25 15
# 24 15
# 25 42
# 26 172
# stop line detected | abort after reaching setted angle
# -- result : 1 -> -190 -- (-192)
# > turn left
# 41 170
# 72 165
# 72 172
# 24 172
# 24 166
# 31 37
# 22 15
# 21 14
# 21 14
# 24 15
# 24 16
# 24 16
# 56 14
# 168 29
# stop line detected | abort after reaching setted angle
# -- result : -1 -> 106 -- (107)
# > turn right
# 164 165
# 98 164
# 130 165
# 163 166
# 161 65
# 161 65
# 167 15
# 167 15
# 33 15
# 26 15
# 23 15
# 23 15
# 21 14
# 26 16
# 28 62
# 28 62
# 26 172
# 65 168
# 166 154
# 171 20
# 171 20
# 167 17
# 66 16
# 23 14
# 18 14
# 18 14
# 25 136
# stop line detected | abort after reaching setted angle
# -- result : 1 -> -204 -- (-206)
# > turn right
# 164 150
# 164 150
# 169 45
# 171 15
# 145 16
# 30 22
# 28 158
# 28 158
# 29 166
# 160 171
# 168 69
# stop line detected | abort before the setted angle is reached
# -- result : -1 -> -90 -- (-89)
# > turn left
# 93 15
# 93 15
# 93 15
# 93 15
# 93 15
# 169 98
# 159 171
# 35 166
# 21 155
# 38 21
# 168 15
# 168 15
# 169 18
# 170 156
# 60 166
# 33 165
# 28 45
# 28 45
# 27 14
# 25 14
# 156 15
# stop line detected | abort before the setted angle is reached
# -- result : -1 -> 173 -- (174)
# > turn right
# 167 113
# 173 145
# 169 87
# 165 15
# 165 15
# 168 16
# 91 17
# 28 15
# 23 15
# 24 37
# 24 37
# 24 161
# stop line detected | abort before the setted angle is reached
# -- result : 1 -> -83 -- (-84)
# > turn left
# 163 165
# 171 143
# 164 162
# 108 171
# 28 165
# 28 165
# 28 165
# 26 19
# 24 15
# 24 15
# 166 16
# 171 18
# 171 143
# 182 143
# 78 163
# 78 163
# 23 166
# 32 60
# 26 15
# 29 14
# 24 15
# 24 15
# 23 17
# 23 17
# 107 16
# stop line detected | abort after reaching setted angle
# -- result : -1 -> 195 -- (196)
# > turn right
# 167 67
# 167 82
# 173 18
# 169 17
# 169 17
# 142 16
# 32 15
# 32 15
# 26 17
# 22 17
# 27 15
# 27 15
# 25 14
# 19 52
# 19 169
# stop line detected | abort after reaching setted angle
# -- result : 2 -> -115 -- (-117)
# > turn left
# 171 90
# 167 117
# 160 158
# 160 158
# 86 159
# 22 167
# 22 167
# 25 15
# 26 15
# 26 15
# 29 13
# 27 16
# 27 15
# 29 15
# 159 15
# 159 15
# 171 16
# 171 153
# 30 169
# 24 63
# 24 63
# 24 14
# 25 15
# 110 13
# stop line detected | abort after reaching setted angle
# -- result : -1 -> 208 -- (210)
# > turn right
# 166 55
# 181 55
# 170 39
# 170 15
# 171 14
# 171 14
# 75 14
# 27 14
# 24 15
# 24 15
# 24 15
# 24 15
# 24 15
# 24 15
# 24 15
# 163 21
# stop line detected | abort after reaching setted angle
# -- result : 1 -> -117 -- (-119)
# > turn left
# 163 21
# 163 21
# 163 21
# 163 21
# 163 21
# 161 26
# 161 26
# 161 26
# 161 26
# 161 26
# 161 26
# 161 26
# 19 15
# 19 15
# 19 15
# 19 15
# 19 15
# 19 15
# 19 15
# 19 15
# 25 160
# 25 160
# stop line detected | abort before the setted angle is reached
# -- result : -1 -> 175 -- (177)
# > turn right
# 168 17
# 166 55
# 167 17
# 171 17
# 171 17
# 171 17
# 42 17
# 25 141
# 26 167
# 123 167
# 167 152
# 167 16
# stop line detected | abort before the setted angle is reached
# -- result : 1 -> -82 -- (-84)
# > turn left
# 73 18
# 73 18
# 101 15
# 169 15
# 171 15
# 171 15
# 166 76
# 160 172
# 37 167
# 26 159
# 26 159
# 56 24
# 170 15
# 168 23
# 170 164
# 41 164
# 41 164
# 27 165
# 27 21
# 25 14
# 27 14
# 158 16
# 158 16
# stop line detected | abort before the setted angle is reached
# -- result : -3 -> 170 -- (173)
# > turn right
# 169 137
# 155 178
# 159 159
# 166 111
# 166 111
# 172 21
# 169 16
# 85 16
# 24 16
# 24 16
# 28 157
# stop line detected | abort before the setted angle is reached
# -- result : 3 -> -83 -- (-86)
# > turn left
# 154 170
# 154 170
# 154 170
# 154 170
# 30 165
# 30 165
# 25 149
# 18 14
# 24 15
# 32 16
# 158 15
# 172 15
# 172 15
# 169 120
# 169 120
# 29 169
# 26 115
# 28 14
# 22 14
# 26 16
# 25 17
# 26 16
# 38 15
# 166 16
# stop line detected | abort after reaching setted angle
# -- result : -1 -> 200 -- (201)
# > turn right
# 165 160
# 169 162
# 169 162
# 169 162
# 164 17
# 169 16
# 91 17
# 26 16
# 28 15
# 28 15
# 23 15
# 20 15
# 26 15
# 23 14
# 23 14
# 25 171
# stop line detected | abort after reaching setted angle
# -- result : 1 -> -117 -- (-119)
# > turn left
# 166 155
# 166 155
# 165 161
# 165 161
# 31 168
# 24 170
# 26 63
# 26 63
# 28 13
# 29 16
# 29 14
# 21 15
# 21 15
# 25 15
# 57 15
# 172 15
# 170 30
# 164 167
# 30 169
# 30 169
# 27 162
# 27 162
# stop line detected | abort before the setted angle is reached
# -- result : -1 -> 168 -- (170)
# > turn right
# 27 162
# 25 15
# 25 15
# 20 15
# 20 15
# 24 17
# 28 18
# 19 163
# 28 172
# 28 172
# 145 106
# 172 106
# stop line detected | abort before the setted angle is reached
# -- result : 1 -> -79 -- (-80)
# > turn left
# 146 17
# 111 14
# 167 17
# 171 17
# 170 45
# 161 165
# 161 165
# 44 169
# 24 165
# 26 14
# 26 14
# 23 15
# 22 14
# 151 15
# 170 15
# 170 15
# 171 141
# 126 167
# 27 165
# 23 107
# 127 17
# stop line detected | abort before the setted angle is reached
# -- result : -1 -> 171 -- (173)
# --------------------------------------------------
#
# > turn left
# stop line detected | abort after reaching setted angle
# -- result : 0 -> 92 -- (92)
# > turn right
# stop line detected | abort after reaching setted angle
# -- result : 1 -> -180 -- (-181)
# > turn left
# stop line detected | abort after reaching setted angle
# -- result : -1 -> 90 -- (92)
# > turn right
# stop line detected | abort after reaching setted angle
# -- result : 2 -> -179 -- (-182)
# > turn left
# stop line detected | abort after reaching setted angle
# -- result : -1 -> 88 -- (90)
# > turn right
# stop line detected | abort after reaching setted angle
# -- result : 1 -> -180 -- (-181)
# > turn left
# stop line detected | abort after reaching setted angle
# -- result : -1 -> 88 -- (90)
# > turn right
# stop line detected | abort after reaching setted angle
# -- result : 1 -> -178 -- (-180)
# > turn left
# stop line detected | abort after reaching setted angle
# -- result : -2 -> 89 -- (91)
# > turn right
# stop line detected | abort after reaching setted angle
# -- result : 1 -> -179 -- (-181)
# > turn left
# stop line detected | abort after reaching setted angle
# -- result : -2 -> 88 -- (91)
# > turn right
# stop line detected | abort after reaching setted angle
# -- result : 1 -> -179 -- (-181)
# > turn left
# stop line detected | abort after reaching setted angle
# -- result : -1 -> 89 -- (91)
# > turn right
# stop line detected | abort after reaching setted angle
# -- result : 1 -> -180 -- (-181)
# > turn left
# stop line detected | abort after reaching setted angle
# -- result : -1 -> 91 -- (93)
# > turn right
# stop line detected | abort after reaching setted angle
# -- result : 1 -> -179 -- (-181)
# > turn right
# stop line detected | abort after reaching setted angle
# -- result : -1 -> -94 -- (-93)
# > turn left
# stop line detected | abort after reaching setted angle
# -- result : -1 -> 180 -- (181)
# > turn right
# stop line detected | abort after reaching setted angle
# -- result : 1 -> -89 -- (-91)
# > turn left
# stop line detected | abort after reaching setted angle
# -- result : -1 -> 179 -- (181)
# > turn right
# stop line detected | abort after reaching setted angle
# -- result : 1 -> -89 -- (-91)
# > turn left
# stop line detected | abort after reaching setted angle
# -- result : -1 -> 180 -- (181)
# > turn right
# stop line detected | abort after reaching setted angle
# -- result : 1 -> -88 -- (-90)
# > turn left
# stop line detected | abort after reaching setted angle
# -- result : -1 -> 178 -- (180)
# > turn right
# stop line detected | abort after reaching setted angle
# -- result : 1 -> -88 -- (-90)
# > turn left
# stop line detected | abort after reaching setted angle
# -- result : -2 -> 179 -- (181)
# > turn right
# stop line detected | abort after reaching setted angle
# -- result : 1 -> -90 -- (-92)
# > turn left
# stop line detected | abort after reaching setted angle
# -- result : -1 -> 178 -- (180)
# > turn right
# stop line detected | abort after reaching setted angle
# -- result : 1 -> -89 -- (-90)
# > turn left
# stop line detected | abort after reaching setted angle
# -- result : -1 -> 179 -- (181)
# > turn right
# stop line detected | abort after reaching setted angle
# -- result : 2 -> -88 -- (-90)
# > turn left
# stop line detected | abort after reaching setted angle
# -- result : -1 -> 179 -- (181)
